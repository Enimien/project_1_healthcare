# %% [markdown]
# #### Title: "Fitbit Analysis"
# #### Author: Enimienlen Lawani
# #### Date: "6/19/2024"
#
# ***
#
#
# # Overview of Project
# Bellabeat is a high-tech manufacturer of health-focused products for women. Bellabeat is a successful small company, but they have the potential to become a larger player in the global smart device. Analyzing smart device fitness data could help unlock new growth opportunities for the company
# market.
#
# ***
#
# # Step 1 - Ask
# ### Business Task
# The business task is to analyze *Fitbit* smart device usage data in order to gain insight into how consumers currently use their smart devices and to discover underlying trends that can be applied to *Bellabeat* products. This insight could help unlock new growth opportunities and the best marketing strategy to meet business growth goals.

# %% [markdown]
# ***
# # Step 2 - Prepare
#
# ### Description of the Dataset
#
# We have used a public dataset that explores smart device users’ daily habits.
#
# Name: FitBit Fitness Tracker Data
# Link: https://www.kaggle.com/
#
# "This Kaggle data set contains personal fitness tracker from fitbit users. Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. It includes information about daily activity, steps, and heart rate that can be used to explore users’ habits.
#
#
# ### Limitations
# * There are limited users. The sample size may not be representative of the population.
# * There are only a few categorical variables to categorize the data for analysis.
# * Each dataset has 30 days of data from 4/12/2016 to 5/12/2016, but the dataset description
#
# ### ROCCC Validation of Dataset
# * Reliable - We will assume this data is accurate and reliable.
# * Original - The data is original as it is directly gathered from users
# * Comprehensive - The data is not comprehensive as it does not have all details needed for a full detailed analysis to meet the business goal
# * Current - The data is not current as the data is from 2016.
# * Cited - The data is cited.
#
# ### Data Summary
# Overall, this data may not be appropriate for conducting a full detailed analysis to meet the goal of the business. However, we will move forward with the data to uncover any insights.
#
# Ideally, we would be having a sample size that is more representative of the whole population, at least 6 months of data from a more current year, and gendered data so that we can gain insight into the specific female trends.
#
# ### Data Sensitivity
# This is public data. No data was identified as sensitive and therefore we will not need to have Data anonymization / De-identification of any data. Also, there is no need to encrypt the data.
#
# ### Setup Environment with Packages

# %% [markdown]
# ## Import library and Read csv files

# %%
        
# import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress
from datetime import datetime as dt


dailyActivity = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv")
dailyCalories = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv")
dailyIntensity = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv")
dailyStep = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv")
heartrate = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv")
hourlyCalories = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv")
hourlyIntensities = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/hourlyIntensities_merged.csv")
hourlySteps = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv")
minuteSleep = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/minuteSleep_merged.csv")
sleepDay = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv")
weightLogInfo = pd.read_csv("Resources/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv")

# %% [markdown]
# ## Preview the datasets

# %%
print("dailyActivity")
print(dailyActivity.head())

print("dailyCalories")
print(dailyCalories.head())

print("dailyIntensity")
print(dailyIntensity.head())

print("dailyStep")
print(dailyStep.head())

print("heartrate_seconds")
print(heartrate.head())

print("hourlyCalories")
print(hourlyCalories.head())

print("hourlyIntensities")
print(hourlyIntensities.head())

print("hourlySteps")
print(hourlySteps.head())

print("minuteSleep")
print(minuteSleep.head())

print("sleepDay")
print(sleepDay.head())

print("weightLogInfo")
print(weightLogInfo.head())
# Out:
# dailyActivity
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863
# dailyCalories
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863
# dailyIntensity
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# 1                 4.71                      0.69                1.57
# 2                 3.91                      0.40                2.44
# 3                 2.83                      1.26                2.14
# 4                 5.04                      0.41                2.71
# dailyStep
#            Id ActivityDay  StepTotal
# 0  1503960366   4/12/2016      13162
# 1  1503960366   4/13/2016      10735
# 2  1503960366   4/14/2016      10460
# 3  1503960366   4/15/2016       9762
# 4  1503960366   4/16/2016      12669
# heartrate_seconds
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101
# hourlyCalories
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48
# hourlyIntensities
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1  1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2  1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3  1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4  1503960366   4/12/2016 4:00:00 AM               0          0.000000
# hourlySteps
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0
# minuteSleep
#            Id                  date  value        logId
# 0  1503960366  4/12/2016 2:47:30 AM      3  11380564589
# 1  1503960366  4/12/2016 2:48:30 AM      2  11380564589
# 2  1503960366  4/12/2016 2:49:30 AM      1  11380564589
# 3  1503960366  4/12/2016 2:50:30 AM      1  11380564589
# 4  1503960366  4/12/2016 2:51:30 AM      1  11380564589
# sleepDay
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712
# weightLogInfo
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %% [markdown]
# ## Cleaning data
#
# ### Check if there are any nulls
# only weighLogInfo dataset has 1 column with null values: Fat (65)
#
# ### Verifying numbers of users
# for each datasets so we which one we can work with

# %%
print("--dailyActivity--")
print(dailyActivity.isna().sum())
print(dailyActivity['Id'].nunique())



print("--dailyCalories--")
print(dailyCalories.isna().sum())
print(dailyCalories['Id'].nunique())

print("--dailyIntensity--")
print(dailyIntensity.isna().sum())
print(dailyIntensity['Id'].nunique())

print("--dailyStep--")
print(dailyStep.isna().sum())
print(dailyStep['Id'].nunique())

print("--heartrate_seconds--")
print(heartrate.isna().sum())
print(heartrate['Id'].nunique())

print("--hourlyCalories--")
print(hourlyCalories.isna().sum())
print(hourlyCalories['Id'].nunique())

print("--hourlyIntensities--")
print(hourlyIntensities.isna().sum())
print(hourlyIntensities['Id'].nunique())

print("--hourlySteps--")
print(hourlySteps.isna().sum())
print(hourlySteps['Id'].nunique())

print("--minuteSleep--")
print(minuteSleep.isna().sum())
print(minuteSleep['Id'].nunique())

print("--sleepDay--")
print(sleepDay.isna().sum())
print(sleepDay['Id'].nunique())

print("--weightLogInfo--")
print(weightLogInfo.isna().sum())
print(weightLogInfo['Id'].nunique())
# Out:
# --dailyActivity--
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64
# 33
# --dailyCalories--
# Id             0
# ActivityDay    0
# Calories       0
# dtype: int64
# 33
# --dailyIntensity--
# Id                          0
# ActivityDay                 0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# dtype: int64
# 33
# --dailyStep--
# Id             0
# ActivityDay    0
# StepTotal      0
# dtype: int64
# 33
# --heartrate_seconds--
# Id       0
# Time     0
# Value    0
# dtype: int64
# 14
# --hourlyCalories--
# Id              0
# ActivityHour    0
# Calories        0
# dtype: int64
# 33
# --hourlyIntensities--
# Id                  0
# ActivityHour        0
# TotalIntensity      0
# AverageIntensity    0
# dtype: int64
# 33
# --hourlySteps--
# Id              0
# ActivityHour    0
# StepTotal       0
# dtype: int64
# 33
# --minuteSleep--
# Id       0
# date     0
# value    0
# logId    0
# dtype: int64
# 24
# --sleepDay--
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64
# 24
# --weightLogInfo--
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64
# 8

# %% [markdown]
# ### Check for duplicates

# %%
dataframes_to_check = [
    ("dailyActivity", dailyActivity),
    ("dailyCalories", dailyCalories),
    ("dailyIntensity", dailyIntensity),
    ("dailyStep", dailyStep),
    ("heartrate", heartrate),
    ("hourlyCalories", hourlyCalories),
    ("hourlyIntensities", hourlyIntensities),
    ("hourlySteps", hourlySteps),
    ("minuteSleep", minuteSleep),
    ("sleepDay", sleepDay),
    ("weightLogInfo", weightLogInfo)
]

for df_name, df in dataframes_to_check:
    duplicate_df = df[df.duplicated()]
    print("Duplicate rows in", df_name)
    print(duplicate_df)
    print("\n")
# Out:
# Duplicate rows in dailyActivity
# Empty DataFrame
# Columns: [Id, ActivityDate, TotalSteps, TotalDistance, TrackerDistance, LoggedActivitiesDistance, VeryActiveDistance, ModeratelyActiveDistance, LightActiveDistance, SedentaryActiveDistance, VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes, Calories]
# Index: []
#
#
# Duplicate rows in dailyCalories
# Empty DataFrame
# Columns: [Id, ActivityDay, Calories]
# Index: []
#
#
# Duplicate rows in dailyIntensity
# Empty DataFrame
# Columns: [Id, ActivityDay, SedentaryMinutes, LightlyActiveMinutes, FairlyActiveMinutes, VeryActiveMinutes, SedentaryActiveDistance, LightActiveDistance, ModeratelyActiveDistance, VeryActiveDistance]
# Index: []
#
#
# Duplicate rows in dailyStep
# Empty DataFrame
# Columns: [Id, ActivityDay, StepTotal]
# Index: []
#
#
# Duplicate rows in heartrate
# Empty DataFrame
# Columns: [Id, Time, Value]
# Index: []
#
#
# Duplicate rows in hourlyCalories
# Empty DataFrame
# Columns: [Id, ActivityHour, Calories]
# Index: []
#
#
# Duplicate rows in hourlyIntensities
# Empty DataFrame
# Columns: [Id, ActivityHour, TotalIntensity, AverageIntensity]
# Index: []
#
#
# Duplicate rows in hourlySteps
# Empty DataFrame
# Columns: [Id, ActivityHour, StepTotal]
# Index: []
#
#
# Duplicate rows in minuteSleep
#                 Id                 date  value        logId
# 99770   4702921684  5/6/2016 9:10:00 PM      3  11573168523
# 99771   4702921684  5/6/2016 9:11:00 PM      3  11573168523
# 99772   4702921684  5/6/2016 9:12:00 PM      2  11573168523
# 99773   4702921684  5/6/2016 9:13:00 PM      1  11573168523
# 99774   4702921684  5/6/2016 9:14:00 PM      1  11573168523
# ...            ...                  ...    ...          ...
# 100308  4702921684  5/7/2016 6:08:00 AM      2  11573168523
# 100309  4702921684  5/7/2016 6:09:00 AM      1  11573168523
# 100310  4702921684  5/7/2016 6:10:00 AM      2  11573168523
# 100311  4702921684  5/7/2016 6:11:00 AM      1  11573168523
# 100312  4702921684  5/7/2016 6:12:00 AM      1  11573168523
#
# [543 rows x 4 columns]
#
#
# Duplicate rows in sleepDay
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 161  4388161847   5/5/2016 12:00:00 AM                  1                 471
# 223  4702921684   5/7/2016 12:00:00 AM                  1                 520
# 380  8378563200  4/25/2016 12:00:00 AM                  1                 388
#
#      TotalTimeInBed
# 161             495
# 223             543
# 380             402
#
#
# Duplicate rows in weightLogInfo
# Empty DataFrame
# Columns: [Id, Date, WeightKg, WeightPounds, Fat, BMI, IsManualReport, LogId]
# Index: []

# %%
dailyActivity['Id'].value_counts()
# Out:
# Id
# 1503960366    31
# 4319703577    31
# 8583815059    31
# 8378563200    31
# 8053475328    31
# 7086361926    31
# 6962181067    31
# 5553957443    31
# 4702921684    31
# 4558609924    31
# 1624580081    31
# 4388161847    31
# 4445114986    31
# 8877689391    31
# 1927972279    31
# 2873212765    31
# 2320127002    31
# 4020332650    31
# 2026352035    31
# 1844505072    31
# 2022484408    31
# 3977333714    30
# 1644430081    30
# 5577150313    30
# 8792009665    29
# 6290855005    29
# 6117666160    28
# 6775888955    26
# 7007744171    26
# 3372868164    20
# 8253242879    19
# 2347167796    18
# 4057192912     4
# Name: count, dtype: int64

# %% [markdown]
# First, we are going to count how many days each participant provided their data. I saw that there is one participant who only provided 4 days of data which is too small and could potentially misdirect our analysis. Hence, we are going to remove it.

# %%
dailyActivity.drop(dailyActivity[dailyActivity['Id'] == 4057192912].index, inplace = True)

# %% [markdown]
# ## Analyzing data
# ## Analyzing data
#
# ### After investigating the datasets, here are the questions we want to ask:
#
# User Activity and Behavior
# - What is the average daily step count for users?
# - How does physical activity vary across different days of the week?
# - What time of day do users typically reach their peak activity levels?
# - How many active minutes do users accumulate daily, and how does this compare to recommended levels?
# - What is the most prominent type of activity: very active, moderate, light, sedentary
# - How long do participants wear smart device throughout the day
# - How does heart rate look like throughout the day in average?
# - What is the average heart rate in days of the week?
#
#
# Since some of the data in the datasets are overlapped, here are the datasets we chose to use:
# - DailyAcitvity
# - Heartrate
#
# The following data manipulation is performed:
#
# 1. Convert *daily_activity["ActivityDate"] to datatime64 dtype.
#     Convert *hourlySteps["ActivityHour"] to datatime64 dtype.
#
# 2. Convert format of ActivityDate to yyyy-mm-dd.
#
# 3. Create new column *DayOfTheWeek* by separating the date into day of the week for further analysis.
#
# 4. Create new column *TotalMins* being the sum of *VeryActiveMinutes*, *FairlyActiveMinutes*, *LightlyActiveMinutes* and *SedentaryMinutes*.
#
# 5. Create new column *TotalHours* by converting new column in #4 to number of hours.
#
# 6. Rearrange and rename columns.

# %%
# convert "ActivityDate" to datatime64 dtype and format to yyyy-mm-dd
df_activity = dailyActivity
df_activity["ActivityDate"] = pd.to_datetime(df_activity["ActivityDate"], format="%m/%d/%Y")
hourlySteps["ActivityDate"] = pd.to_datetime(hourlySteps["ActivityHour"],format =  '%m/%d/%Y %H:%M:%S %p')
heartrate['Time'] = pd.to_datetime(heartrate['Time'], format = '%m/%d/%Y %H:%M:%S %p')

# re-print information to confirm
df_activity.info()
hourlySteps.info()
sleepDay.info()
heartrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 936 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        936 non-null    int64
#  1   ActivityDate              936 non-null    datetime64[ns]
#  2   TotalSteps                936 non-null    int64
#  3   TotalDistance             936 non-null    float64
#  4   TrackerDistance           936 non-null    float64
#  5   LoggedActivitiesDistance  936 non-null    float64
#  6   VeryActiveDistance        936 non-null    float64
#  7   ModeratelyActiveDistance  936 non-null    float64
#  8   LightActiveDistance       936 non-null    float64
#  9   SedentaryActiveDistance   936 non-null    float64
#  10  VeryActiveMinutes         936 non-null    int64
#  11  FairlyActiveMinutes       936 non-null    int64
#  12  LightlyActiveMinutes      936 non-null    int64
#  13  SedentaryMinutes          936 non-null    int64
#  14  Calories                  936 non-null    int64
# dtypes: datetime64[ns](1), float64(7), int64(7)
# memory usage: 117.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   StepTotal     22099 non-null  int64
#  3   ActivityDate  22099 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 690.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    datetime64[ns]
#  2   Value   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 56.8 MB

# %%
#create new list of rearranged columns
new_cols = ['Id', 'ActivityDate', 'DayOfTheWeek', 'TotalSteps', 'TotalDistance', 'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'TotalExerciseMinutes', 'TotalExerciseHours', 'Calories']

# reindex function to rearrange columns based on "new_cols"
df_activity = df_activity.reindex(columns=new_cols)

# print 1st 5 rows to confirm
df_activity.head(5)
# Out:
#            Id ActivityDate  DayOfTheWeek  TotalSteps  TotalDistance  \
# 0  1503960366   2016-04-12           NaN       13162           8.50
# 1  1503960366   2016-04-13           NaN       10735           6.97
# 2  1503960366   2016-04-14           NaN       10460           6.74
# 3  1503960366   2016-04-15           NaN        9762           6.28
# 4  1503960366   2016-04-16           NaN       12669           8.16
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             8.50                       0.0                1.88
# 1             6.97                       0.0                1.57
# 2             6.74                       0.0                2.44
# 3             6.28                       0.0                2.14
# 4             8.16                       0.0                2.71
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.55                 6.06                      0.0
# 1                      0.69                 4.71                      0.0
# 2                      0.40                 3.91                      0.0
# 3                      1.26                 2.83                      0.0
# 4                      0.41                 5.04                      0.0
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                 25                   13                   328
# 1                 21                   19                   217
# 2                 30                   11                   181
# 3                 29                   34                   209
# 4                 36                   10                   221
#
#    SedentaryMinutes  TotalExerciseMinutes  TotalExerciseHours  Calories
# 0               728                   NaN                 NaN      1985
# 1               776                   NaN                 NaN      1797
# 2              1218                   NaN                 NaN      1776
# 3               726                   NaN                 NaN      1745
# 4               773                   NaN                 NaN      1863

# %%
# create new column "day_of_the_week" to represent day of the week
df_activity["DayOfTheWeek"] = df_activity["ActivityDate"].dt.day_name()

# print 1st 5 rows to confirm
df_activity["DayOfTheWeek"].head(5)
# Out:
# 0      Tuesday
# 1    Wednesday
# 2     Thursday
# 3       Friday
# 4     Saturday
# Name: DayOfTheWeek, dtype: object

# %%
# rename columns
df_activity.rename(columns = {"Id":"id", "ActivityDate":"date", "DayOfTheWeek":"day_of_the_week", "TotalSteps":"total_steps", "TotalDistance":"total_dist", "TrackerDistance":"track_dist", "LoggedActivitiesDistance":"logged_dist", "VeryActiveDistance":"very_active_dist", "ModeratelyActiveDistance":"moderate_active_dist", "LightActiveDistance":"light_active_dist", "SedentaryActiveDistance":"sedentary_active_dist", "VeryActiveMinutes":"very_active_mins", "FairlyActiveMinutes":"fairly_active_mins", "LightlyActiveMinutes":"lightly_active_mins", "SedentaryMinutes":"sedentary_mins", "TotalExerciseMinutes":"total_mins","TotalExerciseHours":"total_hours","Calories":"calories"}, inplace = True)

# print column names to confirm
print(df_activity.columns.values)
df_activity.head(5)
# Out:
# ['id' 'date' 'day_of_the_week' 'total_steps' 'total_dist' 'track_dist'
#  'logged_dist' 'very_active_dist' 'moderate_active_dist'
#  'light_active_dist' 'sedentary_active_dist' 'very_active_mins'
#  'fairly_active_mins' 'lightly_active_mins' 'sedentary_mins' 'total_mins'
#  'total_hours' 'calories']
#            id       date day_of_the_week  total_steps  total_dist  track_dist  \
# 0  1503960366 2016-04-12         Tuesday        13162        8.50        8.50
# 1  1503960366 2016-04-13       Wednesday        10735        6.97        6.97
# 2  1503960366 2016-04-14        Thursday        10460        6.74        6.74
# 3  1503960366 2016-04-15          Friday         9762        6.28        6.28
# 4  1503960366 2016-04-16        Saturday        12669        8.16        8.16
#
#    logged_dist  very_active_dist  moderate_active_dist  light_active_dist  \
# 0          0.0              1.88                  0.55               6.06
# 1          0.0              1.57                  0.69               4.71
# 2          0.0              2.44                  0.40               3.91
# 3          0.0              2.14                  1.26               2.83
# 4          0.0              2.71                  0.41               5.04
#
#    sedentary_active_dist  very_active_mins  fairly_active_mins  \
# 0                    0.0                25                  13
# 1                    0.0                21                  19
# 2                    0.0                30                  11
# 3                    0.0                29                  34
# 4                    0.0                36                  10
#
#    lightly_active_mins  sedentary_mins  total_mins  total_hours  calories
# 0                  328             728         NaN          NaN      1985
# 1                  217             776         NaN          NaN      1797
# 2                  181            1218         NaN          NaN      1776
# 3                  209             726         NaN          NaN      1745
# 4                  221             773         NaN          NaN      1863

# %% [markdown]
# ## Activity Data
#
# We will begin by taking a closer look on more specific information surrounding our User Activity and Behavior.
#
# ## What is the average daily step count for users?
#
# How active are they?
#
# We should be able to answer these questions through analysis.

# %%
#round(df_activity["total_steps"].mean(),0)
avg_daily_count = round(df_activity.groupby('id').agg({'total_steps': ['mean']}),0)
avg_daily_count.sort_values('id')
# Out:
#            total_steps
#                   mean
# id
# 1503960366     12117.0
# 1624580081      5744.0
# 1644430081      7283.0
# 1844505072      2580.0
# 1927972279       916.0
# 2022484408     11371.0
# 2026352035      5567.0
# 2320127002      4717.0
# 2347167796      9520.0
# 2873212765      7556.0
# 3372868164      6862.0
# 3977333714     10985.0
# 4020332650      2267.0
# 4319703577      7269.0
# 4388161847     10814.0
# 4445114986      4797.0
# 4558609924      7685.0
# 4702921684      8572.0
# 5553957443      8613.0
# 5577150313      8304.0
# 6117666160      7047.0
# 6290855005      5650.0
# 6775888955      2520.0
# 6962181067      9795.0
# 7007744171     11323.0
# 7086361926      9372.0
# 8053475328     14763.0
# 8253242879      6482.0
# 8378563200      8718.0
# 8583815059      7199.0
# 8792009665      1854.0
# 8877689391     16040.0

# %% [markdown]
# #### Total average step

# %%
round(df_activity["total_steps"].mean(),0)
# Out:
# 7654.0

# %% [markdown]
# The average of total daily steps by the users is 7,638 steps.According to a study conducted in 2011 by BMC/BioMed Central, taking 10,000 steps a day is a reasonable target for healthy adults, helping reduce certain health conditions, such as high blood pressure and heart disease. In order to compare daily steps to an activity level, the following categories can be considered:
#
# **Inactive** - Less than 5,000 steps/day
# **Average** - Between 7,500 and 9,999 steps/day
# **Very Active** - More than 12,500 steps/day
#
# Given the information above, we can conclude that our users fall into the **Average** category. With this in mind, it becomes clear that the users should improve their amount of daily steps for optimal results regarging their health and well-being.

# %% [markdown]
# #### 2. How does physical activity vary across different days of the week?

# %%
df_weekday = df_activity.groupby(df_activity['day_of_the_week']).mean()
df_weekday.filter(['total_steps'])
# Out:
#                  total_steps
# day_of_the_week
# Friday           7475.944000
# Monday           7780.866667
# Saturday         8152.975806
# Sunday           6933.231405
# Thursday         7456.561644
# Tuesday          8143.092715
# Wednesday        7570.013423

# %%
df_weekday['total_steps'].plot.bar(xlabel='Day of the Week', ylabel='Average of Total Steps', title='Average of Total Steps by Day of Week', legend=True, rot=0, figsize=(10,5))
# Out:
# <Axes: title={'center': 'Average of Total Steps by Day of Week'}, xlabel='Day of the Week', ylabel='Average of Total Steps'>

# %% [markdown]
# The resulting plot visually represent the average total steps taken on each day of the week, showing that Saturday and Tuesday have the highest total steps across different days.

# %% [markdown]
# #### 3. What is the most prominent level of active?
# There are 4 types of active, ranging from least to most: sedentary, lightly active, moderately active, very active

# %%
# Average Level of Active

avg_sedentary_min = df_activity["sedentary_mins"].mean()
avg_lightly_min = df_activity["lightly_active_mins"].mean()
avg_fairly_min = df_activity["fairly_active_mins"].mean()
avg_very_min = df_activity["very_active_mins"].mean()

# %%
# Create a dataframe for the Average Level of Active

active_level_data = {
    "active_level": ["SedentaryMinutes", "LightlyActiveMinutes", "FairlyActiveMinutes", "VeryActiveMinutes"],
    "average_min": [avg_sedentary_min, avg_lightly_min, avg_fairly_min, avg_very_min]
}

active_level_df = pd.DataFrame(active_level_data)
active_level_df = active_level_df.set_index("active_level")  # Set "active_level" as the index
print(active_level_df)
# Out:
#                       average_min
# active_level
# SedentaryMinutes       990.244658
# LightlyActiveMinutes   193.196581
# FairlyActiveMinutes     13.616453
# VeryActiveMinutes       21.252137

# %%
explode = [0,0,0,0.2]
active_level_df.plot(kind="pie",y="average_min",title = "Average Active Levels Minutes", explode = explode, autopct = '%1.1f%%',legend=False)

#Hide the ylabel for better appearance
plt.ylabel('') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  Sedentary Minutes have the highest percentage 70.8%  while the lowest minutes is VeryActive. This is quite intuitive as very active minutes are usually spent doing physical exercises, while sedentary minutes and light active minutes are usually sitting, walking. Above pie chart showing "VeryActiveMinutes" slice slightly separated for emphasis.

# %% [markdown]
# #### 4. What time of day do users typically reach their peak activity levels?
#
# What are the most active hours of the users' day on average? Are they occurring during the day or at night?

# %%
hourlySteps.head()
# Out:
#            Id           ActivityHour  StepTotal        ActivityDate
# 0  1503960366  4/12/2016 12:00:00 AM        373 2016-04-12 12:00:00
# 1  1503960366   4/12/2016 1:00:00 AM        160 2016-04-12 01:00:00
# 2  1503960366   4/12/2016 2:00:00 AM        151 2016-04-12 02:00:00
# 3  1503960366   4/12/2016 3:00:00 AM          0 2016-04-12 03:00:00
# 4  1503960366   4/12/2016 4:00:00 AM          0 2016-04-12 04:00:00

# %%
hourlySteps["ActivityHour"]=pd.to_datetime(hourlySteps["ActivityHour"])
hourlySteps["Dayofweek"]=hourlySteps["ActivityHour"].dt.day_name()
# Out:
# C:\Users\enimi\AppData\Local\Temp\ipykernel_46180\3852507629.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   hourlySteps["ActivityHour"]=pd.to_datetime(hourlySteps["ActivityHour"])

# %%
hourlySteps.groupby(hourlySteps["ActivityHour"].dt.hour)['StepTotal'].mean().plot(kind='bar',color='blue',title="Peak Activity Levels of the Day", xlabel="Hour of the day", ylabel="Steps taken", rot=0, figsize=(10,5))
# Out:
# <Axes: title={'center': 'Peak Activity Levels of the Day'}, xlabel='Hour of the day', ylabel='Steps taken'>

# %% [markdown]
# The highest peak activity level is between 6:00pm - 7:00pm

# %% [markdown]
# #### 5. How many active minutes do users accumulate daily
#
# Creating new column *total_mins* being the sum of total active minutes.

# %%
# create new column "total_mins" containing sum of total minutes.
df_activity["total_mins"] = df_activity["very_active_mins"] + df_activity["fairly_active_mins"] + df_activity["lightly_active_mins"] + df_activity["sedentary_mins"]
df_activity["total_mins"].head(5)
# Out:
# 0    1094
# 1    1033
# 2    1440
# 3     998
# 4    1040
# Name: total_mins, dtype: int64

# %%
daily_active_minute = df_activity[['id','total_mins']]
daily_active_minute
# Out:
#              id  total_mins
# 0    1503960366        1094
# 1    1503960366        1033
# 2    1503960366        1440
# 3    1503960366         998
# 4    1503960366        1040
# ..          ...         ...
# 935  8877689391        1440
# 936  8877689391        1440
# 937  8877689391        1440
# 938  8877689391        1440
# 939  8877689391         931
#
# [936 rows x 2 columns]

# %%
daily_avg_active_minute = round(df_activity['total_mins'].mean(), 2) 
daily_avg_active_minute
# Out:
# 1218.31

# %% [markdown]
# 1218.31 is the Average active minutes users accumulate daily

# %% [markdown]
# #### 6. How long do participants wear smart device throughout the day

# %%
# creating new columns : 'wear_percent' contains the wear time percentage each day, 
# 'wear_cat' catagorize wear_percent into catagories where
# 0-25% -> barely
# 25-50% -> less than half of the day
# 50-75% -> more than half of the day
# 75-100% -> most of the day

df_activity['wear_percent'] = df_activity["total_mins"]  / 1440 * 100
df_activity['wear_cat'] = pd.cut(df_activity['wear_percent'], [0, 25, 50 ,75, 100], labels = ['barely', 'less than half day', 'more than half day', 'most of the day'])
df_activity.head()
# Out:
#            id       date day_of_the_week  total_steps  total_dist  track_dist  \
# 0  1503960366 2016-04-12         Tuesday        13162        8.50        8.50
# 1  1503960366 2016-04-13       Wednesday        10735        6.97        6.97
# 2  1503960366 2016-04-14        Thursday        10460        6.74        6.74
# 3  1503960366 2016-04-15          Friday         9762        6.28        6.28
# 4  1503960366 2016-04-16        Saturday        12669        8.16        8.16
#
#    logged_dist  very_active_dist  moderate_active_dist  light_active_dist  \
# 0          0.0              1.88                  0.55               6.06
# 1          0.0              1.57                  0.69               4.71
# 2          0.0              2.44                  0.40               3.91
# 3          0.0              2.14                  1.26               2.83
# 4          0.0              2.71                  0.41               5.04
#
#    sedentary_active_dist  very_active_mins  fairly_active_mins  \
# 0                    0.0                25                  13
# 1                    0.0                21                  19
# 2                    0.0                30                  11
# 3                    0.0                29                  34
# 4                    0.0                36                  10
#
#    lightly_active_mins  sedentary_mins  total_mins  total_hours  calories  \
# 0                  328             728        1094          NaN      1985
# 1                  217             776        1033          NaN      1797
# 2                  181            1218        1440          NaN      1776
# 3                  209             726         998          NaN      1745
# 4                  221             773        1040          NaN      1863
#
#    wear_percent            wear_cat
# 0     75.972222     most of the day
# 1     71.736111  more than half day
# 2    100.000000     most of the day
# 3     69.305556  more than half day
# 4     72.222222  more than half day

# %%
# counting each catagory
wear_cat_count = df_activity.groupby('wear_cat').count()['id'].reset_index().rename(columns = {'id':'count'})
wear_cat_count
# Out:
# C:\Users\enimi\AppData\Local\Temp\ipykernel_46180\55012763.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wear_cat_count = df_activity.groupby('wear_cat').count()['id'].reset_index().rename(columns = {'id':'count'})
#              wear_cat  count
# 0              barely      9
# 1  less than half day     16
# 2  more than half day    346
# 3     most of the day    565

# %%
plt.figure(figsize = (6, 6))
colors = ['#A8A4CE', '#C8B6E2', '#7A86B6', '#495C83']
explode = (0.05,0.05,0.05,0.05)

plt.pie(wear_cat_count['count'], labels=wear_cat_count['wear_cat'], autopct='%.0f%%', colors=colors, explode=explode, pctdistance=0.85)

centre_circle = plt.Circle((0,0),0.70,fc='white')

plt.title('Time worn per day')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the graph above, we can see the distribution of wear categories that more than 60% of participants have been wearing smart device most of the day.

# %% [markdown]
# #### 7. How does heart rate look like throughout the day in average?

# %%
#Create a date column

# heartrate['Date'] = heartrate['Time'].astype(str).str[:10]
# heartrate['Date'] = pd.to_datetime(heartrate['Date'])

#Convert the 'Time' column to datetime objects
#heartrate['Time'] = pd.to_datetime(heartrate['Time'])

# Extract the hour from the 'Time' column and create a new 'Hour' column
heartrate['Hour'] = heartrate['Time'].dt.hour

#check the dtype and Hour column
heartrate.head()


# Group by 'Hour' and calculate the average 'Value' for each group
avg_heart_rate_by_hour = heartrate.groupby('Hour')['Value'].mean().reset_index()

print(avg_heart_rate_by_hour)

avg_heart_rate_by_hour.plot(kind="line", x = 'Hour', y='Value', title = 'Average Heart Rate Throughout a Day', ylabel= 'Average Heart Rate')

plt.show()
# Out:
#     Hour      Value
# 0      1  75.803513
# 1      2  76.044996
# 2      3  73.385546
# 3      4  76.478996
# 4      5  77.735862
# 5      6  81.253800
# 6      7  79.389115
# 7      8  77.920436
# 8      9  78.346034
# 9     10  77.042449
# 10    11  75.652724
# 11    12  78.003410

# %% [markdown]
# The heartrate is higher between 6 and 7

# %% [markdown]
# #### 8. What is the average heart rate in days of the week?

# %%
#Create a date column
heartrate['Date'] = heartrate['Time'].astype(str).str[:10]
heartrate['Date'] = pd.to_datetime(heartrate['Date'])

#create Weekday column based on Date column
heartrate['WeekDay'] = heartrate['Date'].dt.day_name()

#create a function to return a number for a weekday
def get_weekday_NBR(weekday):
    if weekday == "Sunday":
        return 1
    elif weekday == "Monday":
        return 2
    elif weekday == "Tuesday":
        return 3
    elif weekday == "Wednesday":
        return 4
    elif weekday == "Thursday":
        return 5
    elif weekday == "Friday":
        return 6
    else:
        return 7
    
#apply function to get weekday number
heartrate['WeekDayNBR'] = heartrate['WeekDay'].apply(get_weekday_NBR)

#check
print(heartrate)


#calculate average heart rate each week day group by ID
avg_heart_rate_by_weekday = heartrate.groupby(['WeekDay', 'WeekDayNBR'])['Value'].mean().reset_index()

#set index to WeekDayNBR
avg_heart_rate_by_weekday = avg_heart_rate_by_weekday.set_index('WeekDayNBR').sort_index(ascending = True)

#check
print(avg_heart_rate_by_weekday)

#bar chart for average heart rate in week days
avg_heart_rate_by_weekday.plot(kind="bar", x = 'WeekDay', y='Value', title = 'Average Heart Rate Through a Week', ylabel= 'Average Heart Rate')
# Out:
#                  Id                Time  Value  Hour       Date   WeekDay  \
# 0        2022484408 2016-04-12 07:21:00     97     7 2016-04-12   Tuesday
# 1        2022484408 2016-04-12 07:21:05    102     7 2016-04-12   Tuesday
# 2        2022484408 2016-04-12 07:21:10    105     7 2016-04-12   Tuesday
# 3        2022484408 2016-04-12 07:21:20    103     7 2016-04-12   Tuesday
# 4        2022484408 2016-04-12 07:21:25    101     7 2016-04-12   Tuesday
# ...             ...                 ...    ...   ...        ...       ...
# 2483653  8877689391 2016-05-12 02:43:53     57     2 2016-05-12  Thursday
# 2483654  8877689391 2016-05-12 02:43:58     56     2 2016-05-12  Thursday
# 2483655  8877689391 2016-05-12 02:44:03     55     2 2016-05-12  Thursday
# 2483656  8877689391 2016-05-12 02:44:18     55     2 2016-05-12  Thursday
# 2483657  8877689391 2016-05-12 02:44:28     56     2 2016-05-12  Thursday
#
#          WeekDayNBR
# 0                 3
# 1                 3
# 2                 3
# 3                 3
# 4                 3
# ...             ...
# 2483653           5
# 2483654           5
# 2483655           5
# 2483656           5
# 2483657           5
#
# [2483658 rows x 7 columns]
#               WeekDay      Value
# WeekDayNBR
# 1              Sunday  75.925004
# 2              Monday  77.454335
# 3             Tuesday  77.013723
# 4           Wednesday  76.451580
# 5            Thursday  77.035902
# 6              Friday  77.520836
# 7            Saturday  79.973815
# <Axes: title={'center': 'Average Heart Rate Through a Week'}, xlabel='WeekDay', ylabel='Average Heart Rate'>

# %% [markdown]
# The chart will help you understand how heart rate varies on average across different days of the week. Saturday shows the highest average heart rate

# %%
#Convert the 'SleepDay' & 'ActivityDay' to datetime data type
sleepDay['SleepDay'] = pd.to_datetime(sleepDay['SleepDay'])
dailyStep['ActivityDay'] = pd.to_datetime(dailyStep['ActivityDay'])

#left join dailyStep and sleepDay on Id & Date
dailyStep_sleepDay_merge = dailyStep.merge(sleepDay, how='left', left_on=['Id', 'ActivityDay'], right_on=['Id', 'SleepDay'])

dailyStep_sleepDay_merge.head()
# Out:
# C:\Users\enimi\AppData\Local\Temp\ipykernel_46180\154883286.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sleepDay['SleepDay'] = pd.to_datetime(sleepDay['SleepDay'])
#            Id ActivityDay  StepTotal   SleepDay  TotalSleepRecords  \
# 0  1503960366  2016-04-12      13162 2016-04-12                1.0
# 1  1503960366  2016-04-13      10735 2016-04-13                2.0
# 2  1503960366  2016-04-14      10460        NaT                NaN
# 3  1503960366  2016-04-15       9762 2016-04-15                1.0
# 4  1503960366  2016-04-16      12669 2016-04-16                2.0
#
#    TotalMinutesAsleep  TotalTimeInBed
# 0               327.0           346.0
# 1               384.0           407.0
# 2                 NaN             NaN
# 3               412.0           442.0
# 4               340.0           367.0

# %%
#make a scatterplot to check for correlation between StepTotal and TotalMinutesAsleep 
#dailyStep_sleepDay_merge.plot(kind = "scatter", x = 'StepTotal', y = 'TotalMinutesAsleep', grid='True')
plt.scatter(dailyStep_sleepDay_merge["StepTotal"], dailyStep_sleepDay_merge["TotalMinutesAsleep"], color='blue')
plt.xlabel('Total Minutes Asleep')
plt.ylabel('Total Steps')
plt.grid()
plt.show()

# %% [markdown]
# The scatter plot shows that there is no correlation between total steps and minutes asleep

# %% [markdown]
# Perform linear regression on the average steps and calories burnt

# %% [markdown]
# ## Conclusion (Act phase)

# %% [markdown]
# ### Insights and recommendations:

# %% [markdown]
# ###  Recommendations:
# Encourage Consistent Activity:
#
# Given the high amount of sedentary time, users should be encouraged to integrate more active minutes throughout the day.
# Recommendations could include setting hourly reminders to move or integrating short workouts during breaks.
# Leverage Peak Activity Times:
#
# Since users are more active during certain hours, health programs or notifications can be scheduled to coincide with these peak times to enhance engagement.
# For example, sending motivational messages or activity challenges around lunch breaks and after work hours.
# Promote Active Weekends:
#
# If weekends show higher activity, further promote weekend challenges and activities.
# Encourage users to take advantage of their free time on weekends for longer or more intense physical activities.
# Monitor and Increase Device Usage:
#
# For those wearing devices less than "most of the day", provide tips on how to make device-wearing more comfortable and integrate it into daily routines.
# Ensure users understand the importance of wearing the device consistently for accurate activity tracking and health monitoring.
# Heart Rate Awareness:
#
# Use the heart rate data to inform users about their cardiovascular health.
# Provide insights into how their heart rate patterns compare to healthy ranges and suggest activities to improve heart health, such as regular cardiovascular exercises.
# Personalized Activity Plans:
#
# Use the collected data to create personalized activity plans that fit into users' routines and help them reach their fitness goals.
# Tailor recommendations based on individual patterns observed in the data, such as preferred times of day for activity and current activity levels.
# Educational Content:
#
# Provide educational content on the benefits of reducing sedentary time and increasing different levels of activity.
# Offer tips on how to transition from sedentary to lightly, fairly, and very active states gradually.
# Conclusion
# The data analysis provides valuable insights into users' activity patterns and device usage. By leveraging these insights, targeted recommendations and personalized plans can be developed to promote healthier lifestyles and better utilization of activity-tracking devices.
